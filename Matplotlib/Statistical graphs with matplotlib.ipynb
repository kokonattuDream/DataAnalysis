# %% [markdown]
# <img src="../../Pics/MLSb-T.png" width="160">
# <br><br>
# <center><u><H1>Statistical graphs with Matplotlib</H1></u></center>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# %matplotlib inline

# %% [markdown]
# ## <u>Scatter:</u>

# %%
x = np.linspace(-5,5,20)
y = x**2
plt.scatter(x,y)

# %% [markdown]
# ## <u>Scatter Plot Matrix:</u>

# %%
df = pd.DataFrame(np.random.randn(500,4),columns=['v1','v2','v3','v4'])
mat = pd.plotting.scatter_matrix(df, alpha=0.5,
                                       figsize=(8,8),diagonal='kde')
#you can use diagonal='kde'

# %% [markdown]
# ## <u>Bar Chart:</u>

# %% [markdown]
# We have 5 groups of measures of test exams divided by gender and by group. Plot the bar chart.

# %%
N = 5
men_means = (80, 75, 88, 85, 87)
men_std = (5, 3, 2, 4, 5)

ind = np.arange(N)  # the locations on the x axis for the groups
width = 0.4       # the width of the bars

fig, ax = plt.subplots()
r1 = ax.bar(ind, men_means, width, color='r', yerr=men_std)

women_means = (86, 92, 84, 87, 95)
women_std = (8, 9, 3, 3, 6)
r2 = ax.bar(ind + width, women_means, width, color='y', yerr=women_std)

ax.set_ylabel('Test Scores')
ax.set_ylim([0, 150])
ax.set_title('Test Scores by group and gender')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('GR1', 'GR2', 'GR3', 'GR4', 'GR5'))

ax.legend((r1[0], r2[0]), ('Men', 'Women'),loc='best')

def _labels(rects):
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.1*height,
                '%d' % int(height),
                ha='center', va='bottom')

_labels(r1)
_labels(r2)

plt.show()

# %% [markdown]
# ## <u>Histogram:</u>

# %%
x = np.random.sample(50)
n, bins, patches = plt.hist(x, bins=20, facecolor='orange', alpha=0.75, normed=True)
plt.setp(patches[1], 'facecolor', 'r')
plt.xlabel('bins')
plt.ylabel('Values')
plt.grid(True)

plt.show()

# %% [markdown]
# n: is the number of counts in each bin of the histogram
#
# bins: is the left hand edge of each bin
#
# patches: is the individual patches used to create the histogram, e.g a collection of rectangles

# %% [markdown]
# #### Saving figure:

# %%
x = np.random.sample(50)
n, bins, patches = plt.hist(x, bins=20, facecolor='blue', alpha=0.75)
plt.xlabel('bins')
plt.ylabel('Values')
plt.grid(True)
plt.savefig("histogram.png")
plt.show()

# %% [markdown]
# ## <u>Pie Chart:</u>

# %%
# Pie chart, where the slices are ordered and plotted counter-clockwise:
labels = 'Segment 1', 'Segment 2', 'Segment 3', 'Segment 4'
sizes = [20, 15, 45, 20]  # percentages, the sum of all of them must to be 100%
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Segment 2')

fig, ax = plt.subplots()
ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# ## <u>Box Plot:</u>

# %% [markdown]
# <img src="../../Pics/boxplot.jpg" width="250"></img>

# %% [markdown]
# #### Q3: This is the 75th percentile value (upper hinge) of the data.
# #### Q3: This is the 25th percentile value (lower hinge) of the data.
# #### Box: It is a difference between the upper hinge and the lower hinge.
# #### Median: This is the midpoint of the data.
# #### Max: This is the upper inner fence. It is 1.5 times the step above Q3.
# #### Min: This is the lower inner fence. It is 1.5 times the step below Q1.
# #### Any value that is greater than Max or lesser than Min is called an outlier.
# #### approximately 95% or the data are expected to lie between the inner fences

# %%
_high = np.random.rand(20) + 0.5
center = np.random.rand(20)
_low = np.random.rand(20) - 0.5

data = [_high,center,_low]
plt.boxplot(data,vert=True,patch_artist=True)
plt.show()

# %% [markdown]
# ## <u>Bubble Charts:</u>

# %%
plt.style.use('ggplot')
df = pd.DataFrame(np.random.rand(50, 3), columns=['x','y','z'])
df.plot(kind='scatter',x='x',y='y',s=df['z']*400)
# s is the size of the bubble

# %% [markdown]
# ## <u>Heat Maps:</u>

# %%
data = np.random.rand(8,4)
rows = list('12345678')
cols = list('ABCD')
plt.pcolor(data,cmap=plt.cm.Reds,edgecolors='k')
plt.xticks(np.arange(0,4)+0.5,cols)
plt.yticks(np.arange(0,8)+0.5,rows)
plt.show()

# %% [markdown]
# ## <u>3D Plots:</u>

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
img = plt.figure()
ax = Axes3D(img)
x = np.arange(-5,5,0.25)
y = np.arange(-5,5,0.25)
X, Y = np.meshgrid(x, y)
V = np.sqrt(X**2 + Y**2)
Z = np.sin(V)
ax.plot_surface(X,Y,Z, rstride=2, cstride=2, cmap='hot',linewidth=0)

# %% [markdown]
# #### Color bar:

# %%
p = ax.plot_surface(X,Y,Z, rstride=1, cstride=1, cmap='hot',linewidth=0)
img.colorbar(p, shrink=0.5)
img
# The rstride and cstride parameters help in sizing the cell on the surface.

# %% [markdown]
# #### Setting the view angle:

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=0., azim=0)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %%
# setting the view at 50 degrees elevation and 30 degrees angle:
fig = plt.figure()
ax = Axes3D(fig)
ax.view_init(elev=50., azim=30)
ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')

# %% [markdown]
# ## Reference:
#
# https://matplotlib.org/2.0.1/examples/statistics/index.html
